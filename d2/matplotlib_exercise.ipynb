# %% [markdown]
# ## Matplotlib Assignment

# %%
# import pandas
import pandas as pd

# import matplotlib
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('https://raw.githubusercontent.com/digitalminimal/w3/main/d2/company_sales_data.csv')

# %%
df.head(500)
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %% [markdown]
# ### Task 1: Read the `total_profit` of all months and display it using a line plot.

# %%
# 200 random values from the interval <0,15>

# df1=df[df['year']==2020]
x=df['month_number']
y=df['total_profit']
plt.style.use("dark_background")
# plt.style.use("Solarize_Light2")
# a histogram with 20 bins
plt.figure(figsize=(16,9))
plt.plot(x,y,color="#00FF00")
plt.title("Digital Minimal Growth Chart", fontsize=40)
# plt.set_axis_bgcolor('#00FF00')
plt.xlabel("Month of Year",fontsize=30)
plt.ylabel("Revenues",fontsize=30)

plt.show()

# %%
# fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4,figsize=(20, 10))
fig,((ax1,ax2),(ax3, ax4)) = plt.subplots(2, 2,figsize=(20, 10))

ax1.set_xlabel('Month of Year')
ax1.set_ylabel('Revenues')
ax1.set_title('Stateless #1')
x=df['month_number']
y=df['total_profit']
ax1.plot(x,y,'red')

plt.style.use('dark_background')




ax2.plot( df['month_number'], df['facecream'], label="cream")
ax2.plot( df['month_number'], df['facewash'], label="facewash")
ax2.plot( df['month_number'], df['bathingsoap'], label="bathingsoap")
ax2.plot( df['month_number'], df['shampoo'], label="shampoo")
ax2.plot( df['month_number'], df['moisturizer'], label="moisturizer")
ax2.set_title('#2')

x=df['month_number']
y=df['total_profit']
plt.style.use("dark_background")
# lst=[150000,1750000,200000,225000,250000,275000,300000,325000,350000,375000,400000,425000]

ax3.set_title("#3")
ax3.hist(y,bins=6,label="range of profit data") # density=False would make counts

fig.show
# Out:
# <bound method Figure.show of <Figure size 1440x720 with 4 Axes>>

# %% [markdown]
# ### Task 2: Read all the different product sales data and display it using a multiline plot.

# %%
# 200 random values from the interval <0,15>
# Data
# y = df['total_profit']

# multiple line plots
# df2=df[df['year']==2020]
# df3=df[df['year']==2021]
plt.figure(figsize=(16,9))

plt.title("Digital Minimal Growth Chart", fontsize=40)
# plt.set_axis_bgcolor('#00FF00')
# plt.xlabel("Month of Year",fontsize=30)
# plt.ylabel("Revenues",fontsize=30)

plt.style.use("dark_background")
# plt.style.use("Solarize_Light2")
# a histogram with 20 bins

plt.plot( df['month_number'], df['facecream'], label="cream")
plt.plot( df['month_number'], df['facewash'], label="facewash")
plt.plot( df['month_number'], df['bathingsoap'], label="bathingsoap")
plt.plot( df['month_number'], df['shampoo'], label="shampoo")
plt.plot( df['month_number'], df['moisturizer'], label="moisturizer")
# plt.show()

# plt.plot( df3['month_number'], df3['facecream'], label="cream2021")
# plt.plot( df3['month_number'], df3['facewash'], label="facewash2021")
# plt.plot( df3['month_number'], df3['bathingsoap'], label="bathingsoa2021")
# plt.plot( df3['month_number'], df3['shampoo'], label="shampoo2021")
# plt.plot( df3['month_number'], df3['moisturizer'], label="moisturize2021")

# plt.legend()


# plt.plot(df['month_number'],df['total_profit'],color="#00FF00")
#

# %% [markdown]
# ### Task 3: Read the `total_profit` of each month and display it using a histogram to find out which profit ranges are the most common.

# %%
# 200 random values from the interval <0,15>

# df1=df[df['year']==2020]

x=df['month_number']
y=df['total_profit']
plt.style.use("dark_background")
# lst=[150000,1750000,200000,225000,250000,275000,300000,325000,350000,375000,400000,425000]

plt.hist(y,bins=6,label="range of profit data") # density=False would make counts
# Out:
# (array([4., 3., 2., 1., 1., 1.]),
#  array([183300., 221550., 259800., 298050., 336300., 374550., 412800.]),
#  <BarContainer object of 6 artists>)
